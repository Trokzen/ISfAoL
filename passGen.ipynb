# %%
from werkzeug.security import generate_password_hash

# %%
print(generate_password_hash('12345678'))
# Out:
# scrypt:32768:8:1$tK4AGRRfNbr5Pm2c$f51f82663ff87802f9721434667ce5704269d4e7177e41c7e153493d41fab75e5a3006bf337cfea8d4905312036f7a7987e34871c8c6f0d3ed2b5af8b18dbfe8
