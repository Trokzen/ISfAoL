# %%
from passlib.context import CryptContext

# Создаем контекст для хеширования паролей (такой же, как в вашем приложении)
pwd_context = CryptContext(schemes=["bcrypt"], deprecated="auto")

# Пароль, который нужно захешировать
password = "admin"

# Генерируем хэш
hashed_password = pwd_context.hash(password)

print(f"Пароль: {password}")
print(f"Хэш пароля: {hashed_password}")
# Out:
# (trapped) error reading bcrypt version
# Traceback (most recent call last):
#   File "c:\Program Files\Python312\Lib\site-packages\passlib\handlers\bcrypt.py", line 620, in _load_backend_mixin
#     version = _bcrypt.__about__.__version__
#               ^^^^^^^^^^^^^^^^^
# AttributeError: module 'bcrypt' has no attribute '__about__'
# Пароль: admin
# Хэш пароля: $2b$12$GoB6.bFQg8Bg.9wMucmFY.sb/vGjEoET/rgqxFN2tmgAO71sBzs.O
